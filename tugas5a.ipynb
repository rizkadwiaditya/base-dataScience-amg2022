# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("==== soal 1 ====") 
a = 20 
b = 300000
c = 75000
hasil = (a * b) + (a * c)
print("maka pengeluaran gaji + asuransi " +str(hasil))
print("=== b-log ===")
a = 14
b = 360000
c = 75000
hasil = (a * b) + (a * c)
print("maka pengeluaran gaji + asuransi " +str(hasil))
print("=== c-in ===")
a = 28
b = 475000
c = 75000
hasil = (a * b) + (a * c)
print("maka pengeluaran gaji + asuransi " +str(hasil))
print("=== d-namic ===")
a = 42
b = 580000
c = 75000
hasil = (a * b) + (a * c)
print("maka pengeluaran gaji + asuransi " +str(hasil))
print("=== e-psilon  ===")
a = 18
b = 400000
c = 75000
hasil = (a * b) + (a * c)
print("maka pengeluaran gaji + asuransi " +str(hasil))

print("=== soal 2 ===")
pajak = 0.03
aset_a = 0.08
aset_b = 0.04
aset_c = 0.12
aset_d = 0.11
aset_e = 0.03
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000
hasil = (laba_a * pajak) + (aset_a * 280000000)
print("maka total pajak dan utang " +str(hasil))
print("=== b-log ===")
hasil = (laba_b * pajak) + (aset_b * 310000000)
print("maka total pajak dan utang " +str(hasil))
print("=== c-in ===")
hasil = (pajak * laba_c) + (aset_c * 420000000)
print("maka total pajak dan utang " +str(hasil))
print("=== d-namic ===")
hasil = (pajak * laba_d) + (aset_d * 550000000)
print("maka total pajak dan utang " +str(hasil))
print("=== e-psilon ===")
hasil = (pajak * laba_e) + (aset_e * 340000000)
print("maka total pajak dan utang " +str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil =[23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['red', 'green', 'blue']
plt.title("perusahaan")
plt.bar(perusahaan, hasil, color=c)
plt.show()
print("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan= ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
ax.pie(hasil,labels=perusahaan,autopct='%1.2f%%')
plt.title("prusahaan")
plt.show()



print("=== soal 3 ===")
csr1 = 0.25
csr2 = 0.35
aset_a = 280000000
aset_b = 310000000
aset_c = 420000000
aset_d = 550000000
aset_e = 340000000
hasil = (csr1 * 280000000)
print("maka hasil csr setiap perusahaan " +str(hasil))
hasil = (csr2 * 310000000)
print("maka hasil csr setiap perusahaan " +str(hasil))
hasil = (csr2 * 420000000)
print("maka hasil csr setiap perusahaan " +str(hasil))
hasil = (csr2 * 550000000)
print("maka hasil csr setiap perusahaan " +str(hasil))
hasil = (csr2 * 340000000)
print("maka hasil csr setiap perusahaan " +str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil =[70000000.0, 108500000.0, 147000000.0, 192500000.0, 118999999.99999999]
c = ['red', 'green', 'blue']
plt.title("perusahaan")
plt.bar(perusahaan, hasil, color=c)
plt.show()
print("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan= ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil = [70000000.0, 108500000.0, 147000000.0, 192500000.0, 118999999.99999999]
ax.pie(hasil,labels=perusahaan,autopct='%1.2f%%')
plt.title("prusahaan")
plt.show()

print("=== soal 4 ===")
a = 32500000
b = 12
hasil1 = (a * b)
print("maka hasil laba satu pertahun " +str(hasil1))
a = 31000000
hasil2 = (a * b)
print("maka hasil laba satu pertahun " +str(hasil2))
a = 42000000
hasil3 = (a * b)
print("maka hasil laba satu pertahun " +str(hasil3))
a = 51500000
hasil4 = (a * b)
print("maka hasil laba satu pertahun " +str(hasil4))
a = 27000000
hasil5 = (a * b)
print("maka hasil laba satu pertahun " +str(hasil5))

hasil = hasil1 + hasil2 + hasil3 + hasil4 + hasil5
print("maka hasil keseluruhan " +str(hasil))

print("=== soal 5 ===")
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000
AXis = 20
BLog = 14
Cin = 28
DNamic = 42
Epsilon = 18
csr1 = 0.25
csr2 = 0.35
aset_a = 280000000
aset_b = 310000000
aset_c = 420000000
aset_d = 550000000
aset_e = 340000000
hasil = (32500000 * 12) - 0.25 * 280000000 - (7500000 * 12) - 23375000.0
print(""+str(hasil))
hasil = (31000000 * 12) - 0.35 * 310000000 - (6090000 * 12) - 13330000.0
print(""+str(hasil))
hasil = (42000000 * 12) - 0.35 * 420000000 - (15400000 * 12) - 51660000.0
print(""+str(hasil))
hasil = (51500000 * 12) - 0.35 * 550000000 - (27510000 * 12) - 62045000.0
print(""+str(hasil))
hasil = (27000000 * 12) - 0.35 * 340000000 - (8550000 * 12) - 11010000.0
print(""+str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil =[206625000.0, 177090000.0, 120540000.0, 33335000.0, 40355000.0]
c = ['red', 'green', 'blue']
plt.title("perusahaan")
plt.bar(perusahaan, hasil, color=c)
plt.show()
print("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan= ['A-Xis', 'B-Log', 'C-in', 'D-Namic', 'E-psilon']
hasil = [206625000.0, 177090000.0, 120540000.0, 33335000.0, 40355000.0]
ax.pie(hasil,labels=perusahaan,autopct='%1.2f%%')
plt.title("prusahaan")
plt.show()
# Out:
# ==== soal 1 ====
# maka pengeluaran gaji + asuransi 7500000
# === b-log ===
# maka pengeluaran gaji + asuransi 6090000
# === c-in ===
# maka pengeluaran gaji + asuransi 15400000
# === d-namic ===
# maka pengeluaran gaji + asuransi 27510000
# === e-psilon  ===
# maka pengeluaran gaji + asuransi 8550000
# === soal 2 ===
# maka total pajak dan utang 23375000.0
# === b-log ===
# maka total pajak dan utang 13330000.0
# === c-in ===
# maka total pajak dan utang 51660000.0
# === d-namic ===
# maka total pajak dan utang 62045000.0
# === e-psilon ===
# maka total pajak dan utang 11010000.0
# piechart
# === soal 3 ===
# maka hasil csr setiap perusahaan 70000000.0
# maka hasil csr setiap perusahaan 108500000.0
# maka hasil csr setiap perusahaan 147000000.0
# maka hasil csr setiap perusahaan 192500000.0
# maka hasil csr setiap perusahaan 118999999.99999999
# piechart
# === soal 4 ===
# maka hasil laba satu pertahun 390000000
# maka hasil laba satu pertahun 372000000
# ...

# %%
import matplotlib.pyplot as plt
