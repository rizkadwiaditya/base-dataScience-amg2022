# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
print("=== soal no 1 === ")
paskibra = 5
pmr = 18
pramuka = 30
futsal = 7
volly = 16
kesenian = 19
rohis = 12
hasil = (paskibra + pmr) + (pramuka + futsal) + (volly + kesenian + rohis)
print ("hasil dari eskul kelas 10 adalah " + str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
hasil =[5, 18, 30, 7, 16, 19, 12]
c = ['red', 'green', 'blue']
plt.title("ekstrakurikuler")
plt.bar(eskul, hasil, color=c)
plt.show()

print("=== soal no 2 ===")
a = 5
b = 21
c = 6
hasil = (a + b + c)
print ("maka hasil dari eskul paskibra adalah " + str(hasil))
a = 18
b = 4
c = 12
hasil = (a + b + c)
print ("maka hasil dari eskul pmr adalah " + str(hasil))
a = 30
b = 8
c = 24
hasil = (a + b + c)
print ("maka hasil dari eskul pramuka adalah " + str(hasil))
a = 7
b = 29
c = 15
hasil = (a + b + c)
print ("maka hasil dari eskul futsal adalah " + str(hasil))
a = 16
b = 10
c = 12
hasil = (a + b + c)
print ("maka hasil dari eskul volly adalah " + str(hasil))
a = 19
b = 18
c = 4
hasil = (a + b + c)
print ("maka hasil dari eskul kesenian adalah " + str(hasil))
a = 12
b = 10
c = 7
hasil = (a + b + c)
print ("maka hasil dari eskul rohis adalah " + str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
eskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
hasil =[32, 34, 62, 51, 38, 41, 29]
c = ['red', 'green', 'blue',]
plt.title("jumlah siswa yang ikut eskul")
plt.bar(eskul, hasil, color=c)
plt.show()

print("=== soal no 3 ===")
print("olahraga futsal dan volly")
a = 7
b = 29 
c = 15
d = 16
e = 10
f = 12
hasil = (a+b) + (c+d) + (e+f)
print ("maka hasil yang eskul olahraga adalah " + str(hasil))
print ("mengikuti")
a = 107 
b = 100
c = 80
d = 89
hasil = (a + b + c )
total = (hasil - d)
print ("maka hasil yang mengikuti adalah " + str(hasil))
print ("maka hasil yang dikurangi dengan olahraga dan mengikuti adalah " + str(total))
print ("tdk mengikuti")
a = 17 
b = 8
c = 20
hasil = (a + b + c)
print ("hasil dari yang tdk mengikuti " + str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
eskul = ['olahraga', 'mengikuti', 'tdk mengikuti']
hasil =[89, 198, 45]
c = ['red', 'green', 'blue',]
plt.title("jumlah siswa ")
plt.bar(eskul, hasil, color=c)
plt.show() 
print ("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pendidikan = ['olahraga', 'mengikuti', 'tdk mengikuti']
hasil = [89, 198, 45]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.title("eskul")
plt.show()
print("presentaseu")
a = 89
b = 198
c = 45
hasil = (a  + b + c)
print("maka hasil dari seluruhnya adalah " + str(hasil))
pers = a * 100 / hasil
print ("maka hasil presentaseu adalah " + str(pers))
pers = b * 100/ hasil
print ("maka hasil presentaseu adalah " + str(pers))
pers = c * 100 / hasil
print ("maka hasil presentaseu adalah " + str(pers))

print("=== soal no 4 ===")
a = 17 
b = 8
c = 20
hasil = (a + b + c)
print("maka hasil dari tdk mengikuti " + str(hasil))
pers = a * 100 / hasil
print ("maka hasil presentaseu adalah " + str(pers))
pers = b * 100 / hasil
print ("maka hasil presentaseu adalah " + str(pers))
pers = c * 100  / hasil
print ("maka hasil presentaseu adalah " + str(pers))
print ("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas= ['kelas10', 'kelas11', 'kelas12']
hasil = [17, 8, 20]
ax.pie(hasil,labels=kelas,autopct='%1.2f%%')
plt.title("eskul")
plt.show()

print("=== soal no 5 ===")
print ("kelas 10")
a = 5
b = 18
c = 30
d = 7
e = 16
f = 19
g = 12
hasil = (a + b + c + d + e + f + g)
print("maka hasil dari kelas 10 adalah " + str(hasil))
print ("kelas 11")
a = 21
b = 4
c = 8
d = 29
e = 10
f = 18
g = 10
hasil = (a + b + c + d + e + f + g)
print("maka hasil dari kelas 11 adalah " + str(hasil))
print ("kelas 12")
a = 6
b = 12
c = 24
d = 15
e = 12
f = 4
g = 7
hasil = (a + b + c + d + e + f + g)
print("maka hasil dari kelas 12 adalah " + str(hasil))
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
kelas = ['kelas10', 'kelas11', 'kelas12']
hasil =[107, 100, 80]
c = ['red', 'green', 'blue']
plt.title("ekstrakurikuler")
plt.bar(kelas, hasil, color=c)
plt.show()
print("piechart")
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas= ['kelas10', 'kelas11', 'kelas12']
hasil = [107, 100, 80]
ax.pie(hasil,labels=kelas,autopct='%1.2f%%')
plt.title("eskul")
plt.show()
# Out:
# === soal no 1 ===
# hasil dari eskul kelas 10 adalah 107
# === soal no 2 ===
# maka hasil dari eskul paskibra adalah 32
# maka hasil dari eskul pmr adalah 34
# maka hasil dari eskul pramuka adalah 62
# maka hasil dari eskul futsal adalah 51
# maka hasil dari eskul volly adalah 38
# maka hasil dari eskul kesenian adalah 41
# maka hasil dari eskul rohis adalah 29
# === soal no 3 ===
# olahraga futsal dan volly
# maka hasil yang eskul olahraga adalah 89
# mengikuti
# maka hasil yang mengikuti adalah 287
# maka hasil yang dikurangi dengan olahraga dan mengikuti adalah 198
# tdk mengikuti
# hasil dari yang tdk mengikuti 45
# piechart
# presentaseu
# maka hasil dari seluruhnya adalah 332
# maka hasil presentaseu adalah 26.80722891566265
# maka hasil presentaseu adalah 59.63855421686747
# maka hasil presentaseu adalah 13.55421686746988
# === soal no 4 ===
# maka hasil dari tdk mengikuti 45
# maka hasil presentaseu adalah 37.77777777777778
# maka hasil presentaseu adalah 17.77777777777778
# ...
