# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("=== S2 ===")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0

hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari tamat S2 adalah " + str(hasil))
 
print("===S1===")
a = 4
b = 12
c = 6
d = 13
e = 14
f = 0

hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari tamat S1 adalah " + str(hasil))
print("===SMA===")
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75

hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari tamat SMA  adalah " + str(hasil))
print("===SMP===")
a = 5
b = 6
c = 15
d = 9
e = 20
f = 15
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari tamat SMP adalah " + str(hasil))
print("===SD===")
a = 1
b = 8
c = 0
d = 19
e = 10
f = 1

hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari SD adalah " + str(hasil))
print("=== TIDAK DIKETAHUI ===")
a = 2
b = 14
c = 3
d = 10
e = 0
f = 1

hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari SD adalah " + str(hasil))

print("== NO 2 ==")
a = 17
b = 0.25
hasil = ( 17 * 0.25)
print ("hasil dari S2 adalah " + str(hasil))
a = 49
b = 0.2
hasil = ( 49 * 0.20)
print("hasil dari S1 adalah " + str(hasil))
a = 140
b = 0.15
hasil = ( 140 * 0.15)
print("hasil dari SMA adalah " + str(hasil))
a = 70
b = 0.10
hasil = ( 70 * 0.10)
print("hasil dari SMP adalah " + str(hasil))
a = 39
b = 0.5
hasil = ( 39 * 0.5)
print("hasil dari SD adalah " + str(hasil))
a = 30
b = 0.3
hasil = ( 30 * 0.3)
print("hasil dari S1 adalah " + str(hasil))

print("== NO 3 ==")
a = 0
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 4
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 12
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 5
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 1
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 2
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))

a = 0.0
b = 0.8
c = 1.7999999999999998
d = 0.5
e = 0.5
f = 0.6
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >70 adalah " + str(hasil))
print("==rentang usia >60==")
a = 1
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 12
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 17
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 6
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 8
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 14
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))

a = 0.25
b = 2.4000000000000004
c = 2.55
d = 0.6000000000000001
e = 4.0
f = 4.2
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >60 adalah " + str(hasil))
print("==rentang usia >50==")
a = 4
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 6
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 5
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 15
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 0
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 3
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))
a = 1.0
b = 1.2000000000000002
c = 0.75
d = 1.5
e = 0.0
f = 0.8999999999999999
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >50 adalah " + str(hasil))
print("==rentang usia >40==")
a = 7
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 13
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 20
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 9
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 19
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 10
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))
a = 1.75
b = 2.6
c = 3.0
d = 0.9
e = 9.5
f = 3.0
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >40 adalah " + str(hasil))
print("==rentang usia >30==")
a = 5
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 14
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 11
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 20
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 10
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 0
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))
a = 1.25
b = 2.8000000000000003
c = 1.65
d = 2.0
e = 5.0
f = 0.0
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >30 adalah " + str(hasil))
print("==rentang usia >20==")
a = 0
b = 0.25
hasil = (a * b)
print("hasil dari s2 adalah " + str(hasil))
a = 0
b = 0.20
hasil = (a * b)
print("hasil dari s1 adalah " + str(hasil))
a = 75
b = 0.15
hasil = (a * b)
print("hasil dari SMA adalah " + str(hasil))
a = 15
b = 0.10
hasil = (a * b)
print("hasil dari SMP adalah " + str(hasil))
a = 1
b = 0.5
hasil = (a * b)
print("hasil dari SD adalah " + str(hasil))
a = 1
b = 0.3
hasil = (a * b)
print("hasil dari TIDAK DIKETAHUI adalah " + str(hasil))
a = 0.0
b = 0.0
c = 11.25
d = 1.5
e = 0.5
f = 0.3
hasil = ( a + b ) + ( c + d ) + ( e + f )
print ("hasil dari usia >20 adalah " + str(hasil))

print("== NO 4==")
minz = [4.199999999999999]
print("maka yang paling kecil dari rentang pendidikan adalah >70 " + str(minz))
# Out:
# === S2 ===
# hasil dari tamat S2 adalah 17
# ===S1===
# hasil dari tamat S1 adalah 49
# ===SMA===
# hasil dari tamat SMA  adalah 140
# ===SMP===
# hasil dari tamat SMP adalah 70
# ===SD===
# hasil dari SD adalah 39
# === TIDAK DIKETAHUI ===
# hasil dari SD adalah 30
# == NO 2 ==
# hasil dari S2 adalah 4.25
# hasil dari S1 adalah 9.8
# hasil dari SMA adalah 21.0
# hasil dari SMP adalah 7.0
# hasil dari SD adalah 19.5
# hasil dari S1 adalah 9.0
# == NO 3 ==
# hasil dari s2 adalah 0.0
# hasil dari s1 adalah 0.8
# hasil dari SMA adalah 1.7999999999999998
# hasil dari SMP adalah 0.5
# hasil dari SD adalah 0.5
# hasil dari TIDAK DIKETAHUI adalah 0.6
# hasil dari usia >70 adalah 4.199999999999999
# ==rentang usia >60==
# hasil dari s2 adalah 0.25
# hasil dari s1 adalah 2.4000000000000004
# hasil dari SMA adalah 2.55
# hasil dari SMP adalah 0.6000000000000001
# hasil dari SD adalah 4.0
# hasil dari TIDAK DIKETAHUI adalah 4.2
# hasil dari usia >60 adalah 14.0
# ==rentang usia >50==
# ...

# %%
import matplotlib.pyplot as plt

# %%
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'TDK']
hasil =[17, 49, 140, 70, 39, 30]
c = ['red', 'green', 'blue']
plt.title("pendidikan")
plt.bar(pendidikan, hasil, color=c)
plt.show()
#cara menampilkan grafik bar
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
usia = ['70', '60', '50', '40', '30', '20']
total =[4.199999999999999, 14.0, 5.35, 20.75, 12.700000000000001, 13.55]
c = ['red', 'green', 'blue']
plt.title("usia")
plt.bar(usia, total, color=c)
plt.show()

# %%
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'TDK']
hasil = [17, 49, 140, 70, 39, 30]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.title("pendidikan")
plt.show()
# pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pendidikan = ['70', '60', '50', '40', '30', '20']
hasil =[4.199999999999999, 14.0, 5.35, 20.75, 12.700000000000001, 13.55]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.title("usia")
plt.show()
